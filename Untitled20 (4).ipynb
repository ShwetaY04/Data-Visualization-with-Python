# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')
df.shape
# Out:
# (244, 7)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#. Show 5 random data records

r=0
import random 
for i in range(1,6): 
    r=random.randint(0,245)
    print(df.iloc[r,:])
# Out:
# total_bill     15.77
# tip             2.23
# sex           Female
# smoker            No
# day              Sat
# time          Dinner
# size               2
# Name: 22, dtype: object
# total_bill     27.18
# tip              2.0
# sex           Female
# smoker           Yes
# day              Sat
# time          Dinner
# size               2
# Name: 240, dtype: object
# total_bill    15.98
# tip            2.03
# sex            Male
# smoker           No
# day            Thur
# time          Lunch
# size              2
# Name: 84, dtype: object
# total_bill       9.6
# tip              4.0
# sex           Female
# smoker           Yes
# day              Sun
# time          Dinner
# size               2
# Name: 178, dtype: object
# total_bill    22.76
# tip             3.0
# sex            Male
# smoker           No
# day            Thur
# time          Lunch
# size              2
# Name: 78, dtype: object

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
from sklearn import datasets, linear_model

# %%
#. Linear regression plots between the features 'total_bill' and 'tip'

import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
#Who usually give more tips, Male or Female? Explain with a graph
plt.figure(figsize=(10, 5))
sns.barplot(x='sex',y='tip',data=df)
plt.show()

# %% [markdown]
# Male pays more tips then female

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
#Which meal provides more tips? Explain with a graph
plt.figure(figsize=(10, 5))
sns.barplot(x='tip',y='time',data=df)
plt.show()

# %% [raw]
# Dinner provides more tips

# %%
#5. Whoich day usually good for tips? Explain with a graph
plt.figure(figsize=(10, 5))
sns.barplot(x='tip',y='day',data=df)
plt.show()

# %%
Sunday usually go for tips

# %%
#6. What type of skewness total_bill has in the dataset (positive ornegative)? Justify and explain with a graph.
sns.displot(df, x="total_bill", kind="kde")

# %% [markdown]
#  It is positive skewness, it causes the mean to be greater than the median and eventually move to the right.
